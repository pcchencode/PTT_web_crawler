# %%
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime as dt
import random
import time 
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %% [markdown]
# ## 先只爬一篇文章的資訊、推文留言

# %%
payload={
'from':'/bbs/'+ 'Gossiping' +'/index.html',
'yes':'yes' 
}

url = 'https://www.ptt.cc/bbs/Examination/M.1582260742.A.8D9.html'
#url = 'https://www.ptt.cc/bbs/sex/M.1582985884.A.88A.html'
#url = 'https://www.ptt.cc/bbs/LoL/M.1583142390.A.3A0.html'
#破除18禁的限制
rs = requests.session()
req = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
req = rs.get('https://www.ptt.cc/bbs/'+ 'sex' +'/index.html',verify = False)
req = rs.get(url, verify=False)

# %%
#200 means get success, 404 means fail
req.status_code
# Out:
# 200

# %%
web_content = req.text
#以美味湯解析html
soup = BeautifulSoup(web_content, 'lxml')

# %%
main_content = soup.find('div',id="main-content")
metas = main_content.select('div.article-metaline')

# %%
author = metas[0].select('span.article-meta-value')[0].text
title = metas[1].select('span.article-meta-value')[0].text
post_date = metas[2].select('span.article-meta-value')[0].text

# %%
author_ID = author.split('(',1)[0].replace(' ','')
author_name = author.split('(',1)[1].replace(')','')

# %%
#content篩選出文章內文
content = soup.find(id="main-content").text
target_content=u'※ 發信站: 批踢踢實業坊(ptt.cc),'
content = content.split(target_content)
date = soup.select('.article-meta-value')[3].text
content = content[0].split(date)
content = content[1].replace('\n', '  ').replace('\t', '  ')

# %%
note = soup.select('span.f2')

# %%
org_url = note[1].text.replace('※ 文章網址: ','')

# %%
createdTime = dt.datetime.today().strftime("%d/%m/%Y %H:%M:%S")

# %%
createdTime
# Out:
# '03/03/2020 19:07:05'

# %%
post_info = []
post_info.append({'authorId':author_ID, 'authorName':author_name, 'title':title, 'publishedTime':post_date
                  , 'content':content, 'canonicalUrl':org_url, 'createdTime':createdTime})

# %%
post_info = pd.DataFrame(post_info)

# %%
pushes = main_content.find_all('div', class_='push')

# %%
messages = []
for push in pushes:
    push_tag = push.find('span', 'push-tag').string.strip(' \t\n\r')
    push_userid = push.find('span', 'push-userid').string.strip(' \t\n\r')
    # if find is None: find().strings -> list -> ' '.join; else the current way
    push_content = push.find('span', 'push-content').strings
    push_content = ' '.join(push_content)[1:].strip(' \t\n\r')  # remove ':'
    push_ipdatetime = push.find('span', 'push-ipdatetime').string.strip(' \t\n\r')    
    messages.append( {'canonicalUrl':org_url, 'push_tag': push_tag, 'commentId': push_userid
                      , 'commentContent': push_content, 'commentTime': push_ipdatetime} )

# %%
messages = pd.DataFrame(messages)

# %%
messages
# Out:
#                                          canonicalUrl push_tag  commentId  \
# 0   https://www.ptt.cc/bbs/Examination/M.158226074...        推   milk7054
# 1   https://www.ptt.cc/bbs/Examination/M.158226074...        →   milk7054
# 2   https://www.ptt.cc/bbs/Examination/M.158226074...        →   milk7054
# 3   https://www.ptt.cc/bbs/Examination/M.158226074...        推    needeng
# 4   https://www.ptt.cc/bbs/Examination/M.158226074...        →    needeng
# ..                                                ...      ...        ...
# 65  https://www.ptt.cc/bbs/Examination/M.158226074...        推    Curry16
# 66  https://www.ptt.cc/bbs/Examination/M.158226074...        →    Curry16
# 67  https://www.ptt.cc/bbs/Examination/M.158226074...        推  h14753951
# 68  https://www.ptt.cc/bbs/Examination/M.158226074...        推  h14753951
# 69  https://www.ptt.cc/bbs/Examination/M.158226074...        推    NTUTPTT
#
#                 commentContent  commentTime
# 0           第一年剛開始打底就別想太多，先當練筆  02/21 13:04
# 1     6科專業，每科20章，一天看一科，這樣根本來不及  02/21 13:09
# 2              光函授看完第一輪就差不多要考試  02/21 13:10
# 3   準時下班，怎會沒辦法看書？平日不行的話，你放假有看書  02/21 13:42
# 4                    ？你的企圖心不夠。  02/21 13:42
# ..                         ...          ...
# 65  人家全職考生窮到每天被家人念，你有薪水領，本來就要比  02/24 07:26
# 66                         較努力  02/24 07:26
# 67        過太爽就會沒動力念書,沒有壓力就沒有動力  02/24 12:23
# 68                你應該好好找一下動力來源  02/24 12:27
# 69            同意樓上，我也跟原po有類似狀況  03/01 10:23
#
# [70 rows x 5 columns]

# %%
pd.merge(post_info, messages, how='left', on='canonicalUrl')
# Out:
#    authorId authorName            title             publishedTime  \
# 0   oiuyman        man  [請益] 兼職考該怎麼安排時間  Fri Feb 21 12:52:20 2020
# 1   oiuyman        man  [請益] 兼職考該怎麼安排時間  Fri Feb 21 12:52:20 2020
# 2   oiuyman        man  [請益] 兼職考該怎麼安排時間  Fri Feb 21 12:52:20 2020
# 3   oiuyman        man  [請益] 兼職考該怎麼安排時間  Fri Feb 21 12:52:20 2020
# 4   oiuyman        man  [請益] 兼職考該怎麼安排時間  Fri Feb 21 12:52:20 2020
# ..      ...        ...              ...                       ...
# 65  oiuyman        man  [請益] 兼職考該怎麼安排時間  Fri Feb 21 12:52:20 2020
# 66  oiuyman        man  [請益] 兼職考該怎麼安排時間  Fri Feb 21 12:52:20 2020
# 67  oiuyman        man  [請益] 兼職考該怎麼安排時間  Fri Feb 21 12:52:20 2020
# 68  oiuyman        man  [請益] 兼職考該怎麼安排時間  Fri Feb 21 12:52:20 2020
# 69  oiuyman        man  [請益] 兼職考該怎麼安排時間  Fri Feb 21 12:52:20 2020
#
#                                               content  \
# 0     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...
# 1     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...
# 2     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...
# 3     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...
# 4     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...
# ..                                                ...
# 65    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...
# 66    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...
# 67    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...
# 68    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...
# 69    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...
#
#                                          canonicalUrl          createdTime  \
# 0   https://www.ptt.cc/bbs/Examination/M.158226074...  03/03/2020 19:07:05
# 1   https://www.ptt.cc/bbs/Examination/M.158226074...  03/03/2020 19:07:05
# 2   https://www.ptt.cc/bbs/Examination/M.158226074...  03/03/2020 19:07:05
# 3   https://www.ptt.cc/bbs/Examination/M.158226074...  03/03/2020 19:07:05
# 4   https://www.ptt.cc/bbs/Examination/M.158226074...  03/03/2020 19:07:05
# ..                                                ...                  ...
# 65  https://www.ptt.cc/bbs/Examination/M.158226074...  03/03/2020 19:07:05
# 66  https://www.ptt.cc/bbs/Examination/M.158226074...  03/03/2020 19:07:05
# 67  https://www.ptt.cc/bbs/Examination/M.158226074...  03/03/2020 19:07:05
# 68  https://www.ptt.cc/bbs/Examination/M.158226074...  03/03/2020 19:07:05
# 69  https://www.ptt.cc/bbs/Examination/M.158226074...  03/03/2020 19:07:05
#
#    push_tag  commentId              commentContent  commentTime
# 0         推   milk7054          第一年剛開始打底就別想太多，先當練筆  02/21 13:04
# 1         →   milk7054    6科專業，每科20章，一天看一科，這樣根本來不及  02/21 13:09
# 2         →   milk7054             光函授看完第一輪就差不多要考試  02/21 13:10
# 3         推    needeng  準時下班，怎會沒辦法看書？平日不行的話，你放假有看書  02/21 13:42
# 4         →    needeng                   ？你的企圖心不夠。  02/21 13:42
# ..      ...        ...                         ...          ...
# 65        推    Curry16  人家全職考生窮到每天被家人念，你有薪水領，本來就要比  02/24 07:26
# 66        →    Curry16                         較努力  02/24 07:26
# 67        推  h14753951        過太爽就會沒動力念書,沒有壓力就沒有動力  02/24 12:23
# 68        推  h14753951                你應該好好找一下動力來源  02/24 12:27
# 69        推    NTUTPTT            同意樓上，我也跟原po有類似狀況  03/01 10:23
#
# [70 rows x 11 columns]

# %% [markdown]
# ## 抓某個看板的某個頁面的所有文章網址

# %%
payload={
'from':'/bbs/'+ 'sex' +'/index.html',
'yes':'yes' 
}

url = 'https://www.ptt.cc/bbs/Examination/index.html'
#破除18禁的限制
rs = requests.session()
req = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
req = rs.get('https://www.ptt.cc/bbs/'+ 'sex' +'/index.html',verify = False)
req = rs.get(url, verify=False)
# Out:
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
#200 means get success, 404 means fail
req.status_code
# Out:
# 200

# %%
web_content = req.text
#以美味湯解析html
soup = BeautifulSoup(web_content, 'lxml')

# %%
post_list = soup.find_all('div',class_="title")

# %%
url_list = []
for item in post_list:
    try:
        url_list.append('https://www.ptt.cc'+item.select_one("a").get("href"))
    except: #刪文抓不到href
        pass

# %%
#得到該頁面的所有url
url_list
# Out:
# ['https://www.ptt.cc/bbs/Examination/M.1582969553.A.FEE.html',
#  'https://www.ptt.cc/bbs/Examination/M.1582979626.A.822.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583037348.A.AC9.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583038395.A.B8B.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583050146.A.269.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583050709.A.EB4.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583057947.A.E9E.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583069018.A.29E.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583075191.A.D9E.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583120282.A.3DB.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583133271.A.B3B.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583149220.A.F93.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583151717.A.0B7.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583160130.A.221.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583201813.A.888.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583216252.A.6F5.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583225436.A.598.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583230839.A.EB3.html',
#  'https://www.ptt.cc/bbs/Examination/M.1526743284.A.A58.html',
#  'https://www.ptt.cc/bbs/Examination/M.1494205695.A.25E.html',
#  'https://www.ptt.cc/bbs/Examination/M.1563990333.A.6C1.html']

# %% [markdown]
# * 抓取該看板的總頁數

# %%
board = 'sex'
pre_num = soup.select('div.btn-group > a')[3]['href'].replace('/bbs/'+board+'/index','') ##
pre_num = pre_num.replace('.html','')
total_page_index = pd.to_numeric(pre_num)+1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "/bbs/Examination/index3007"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-40326cd7e237> in <module>
#       2 pre_num = soup.select('div.btn-group > a')[3]['href'].replace('/bbs/'+board+'/index','') ##
#       3 pre_num = pre_num.replace('.html','')
# ----> 4 total_page_index = pd.to_numeric(pre_num)+1
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     149             coerce_numeric = errors not in ("ignore", "raise")
#     150             values = lib.maybe_convert_numeric(
# --> 151                 values, set(), coerce_numeric=coerce_numeric
#     152             )
#     153
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "/bbs/Examination/index3007" at position 0

# %%
total_page_index
# Out:
# 3008

# %%
for i in range(3008,3002,-1):
    print(i)
# Out:
# 3008
# 3007
# 3006
# 3005
# 3004
# 3003

# %% [markdown]
# # 得到一篇文章資訊的function

# %%
def get_post_data(post_url):
    payload={
    'from':'/bbs/'+ 'Gossiping' +'/index.html',
    'yes':'yes' 
    }

    #破除18歲的限制
    rs = requests.session()
    req = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
    req = rs.get('https://www.ptt.cc/bbs/'+ 'Gossiping' +'/index.html',verify = False)
    req = rs.get(post_url, verify=False)

    if req.status_code==200:
        web_content = req.text
        #以美味湯解析html
        soup = BeautifulSoup(web_content, 'lxml')
        main_content = soup.find('div',id="main-content")
        metas = main_content.select('div.article-metaline')

        author = metas[0].select('span.article-meta-value')[0].text
        title = metas[1].select('span.article-meta-value')[0].text
        post_date = metas[2].select('span.article-meta-value')[0].text
        author_ID = author.split('(',1)[0].replace(' ','')
        author_name = author.split('(',1)[1].replace(')','')

        #content篩選出文章內文
        content = soup.find(id="main-content").text
        target_content=u'※ 發信站: 批踢踢實業坊(ptt.cc),'
        content = content.split(target_content)
        date = soup.select('.article-meta-value')[3].text
        content = content[0].split(date)
        content = content[1].replace('\n', '  ').replace('\t', '  ')

        #note = soup.select('span.f2')
        #org_url = note[1].text.replace('※ 文章網址: ','')
        createdTime = dt.datetime.today().strftime("%d/%m/%Y %H:%M:%S")
        post_info = []
        post_info.append({'authorId':author_ID, 'authorName':author_name, 'title':title, 'publishedTime':post_date
                          , 'content':content, 'canonicalUrl':post_url, 'createdTime':createdTime})
        post_info = pd.DataFrame(post_info)

        pushes = main_content.find_all('div', class_='push')
        messages = []
        for push in pushes:
            push_tag = push.find('span', 'push-tag').string.strip(' \t\n\r')
            push_userid = push.find('span', 'push-userid').string.strip(' \t\n\r')
            # if find is None: find().strings -> list -> ' '.join; else the current way
            push_content = push.find('span', 'push-content').strings
            push_content = ' '.join(push_content)[1:].strip(' \t\n\r')  # remove ':'
            push_ipdatetime = push.find('span', 'push-ipdatetime').string.strip(' \t\n\r')    
            messages.append( {'canonicalUrl':post_url, 'push_tag': push_tag, 'commentId': push_userid
                              , 'commentContent': push_content, 'commentTime': push_ipdatetime} )

        messages = pd.DataFrame(messages)

        #post_data = pd.merge(post_info, messages, how='left', on='canonicalUrl')

        return post_info, messages

    else:
        return "404"

# %%
get_post_data('https://www.ptt.cc/bbs/Gossiping/M.1583233903.A.A4C.html')[1]
# Out:
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
#                                          canonicalUrl push_tag     commentId  \
# 0   https://www.ptt.cc/bbs/Gossiping/M.1583233903....        →   WolfTeacher
# 1   https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推   foolfighter
# 2   https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推     kenek0612
# 3   https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推    DiMammaMia
# 4   https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推        kaiyao
# 5   https://www.ptt.cc/bbs/Gossiping/M.1583233903....        →      will0620
# 6   https://www.ptt.cc/bbs/Gossiping/M.1583233903....        →      Yude0109
# 7   https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推  railwaytaiwa
# 8   https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推       patiger
# 9   https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推           hqu
# 10  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推    reuentahlv
# 11  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        →          kify
# 12  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推      msicetea
# 13  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推    patentshit
# 14  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推    Gold740716
# 15  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        →          olli
# 16  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推        canson
# 17  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推        NBC427
# 18  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推         Gsanz
# 19  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓       oiixooi
# 20  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        →       Kazmier
# 21  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        →     calculus9
# 22  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推   sheepmeamea
# 23  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推      colenken
# 24  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓       Luismth
# 25  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推    woody78963
# 26  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓         no321
# 27  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓      zxc17893
# 28  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        →    WeAntiTVBS
# 29  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推       Brad255
# 30  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓       ttykimo
# 31  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓     linkinpk6
# 32  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推     jessicali
# 33  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓   flymomo2001
# 34  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓      toast122
# 35  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        →        dlevel
# 36  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        →      seraph01
# 37  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推   Lamuneforty
# 38  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推    zxc1234529
# 39  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推    godchildtw
# 40  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓       asuknow
# 41  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓     david0426
# 42  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        →  kennetharies
# 43  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓       Argyris
# 44  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓       yangkun
# 45  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        →       ezorttc
# 46  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推         sd785
# 47  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推      Chia2323
# 48  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓     yu1111116
# 49  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓          kilu
# 50  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓        ha0118
# 51  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        推         royfw
# 52  https://www.ptt.cc/bbs/Gossiping/M.1583233903....        噓        Chauge
#
#     commentContent                  commentTime
# 0             嘔嘔嘔嘔    180.176.0.145 03/03 19:11
# 1            衣索比亞狗  223.137.205.227 03/03 19:12
# 2             五樓的洨     39.12.42.254 03/03 19:12
# 3            送他上西天   114.136.47.217 03/03 19:12
# 4     送他巧克力，祝他要到手指   111.241.103.23 03/03 19:12
# 5            祖國的善液   223.136.24.151 03/03 19:12
# 6            R.I.P    59.115.68.236 03/03 19:12
# 7      祝他像老柯一樣拉肚……   36.237.211.250 03/03 19:12
# 8            請他吃拔辣    114.39.84.185 03/03 19:12
# 9        阿兩也是這一天生日      42.77.65.70 03/03 19:13
# 10         送他習維尼裸照    114.41.32.216 03/03 19:13
# 11   跟兩津同一天，難怪這麼愛錢     115.82.4.180 03/03 19:13
# 12             好無聊   184.22.115.202 03/03 19:14
# 13       湖北七日遊豪華行程   114.136.165.22 03/03 19:14
# 14             人民幣   140.113.127.95 03/03 19:14
# 15        我還以為他70了  123.193.118.190 03/03 19:14
# 16            厲害了。     115.69.33.92 03/03 19:16
# 17           R.I P   123.192.89.194 03/03 19:16
# 18            兩津勘吉    114.46.16.150 03/03 19:16
# 19            生日快樂   223.136.19.182 03/03 19:17
# 20           中國養的狗     111.83.54.66 03/03 19:17
# 21              笑屁     101.15.165.6 03/03 19:17
# 22      送他去武漢七天六日遊   110.50.146.170 03/03 19:17
# 23          希望變牠忌日    61.231.40.122 03/03 19:17
# 24   嘔嘔嘔嘔嘔 送他去武漢慶生     27.247.74.30 03/03 19:18
# 25          武漢肺炎病毒  101.137.145.206 03/03 19:18
# 26           R.I.H    36.236.120.92 03/03 19:18
# 27           r.i.p  182.234.160.141 03/03 19:18
# 28           譚德塞林良     114.25.80.11 03/03 19:19
# 29             罐頭塔    219.91.75.147 03/03 19:20
# 30             彈到屎    36.230.56.216 03/03 19:20
# 31             RIP    42.73.240.212 03/03 19:20
# 32          祝他聚餐得病  223.136.102.125 03/03 19:21
# 33            牲日快樂    101.9.144.113 03/03 19:22
# 34         希望生日變忌日    49.216.61.158 03/03 19:22
# 35              刀片     42.74.106.40 03/03 19:23
# 36       世界還要容忍他多久    111.253.38.15 03/03 19:23
# 37             譚額頭    27.246.75.232 03/03 19:23
# 38          怎麼不是忌日    115.43.90.147 03/03 19:28
# 39   還以為是忌日，害我高興一下      210.69.89.2 03/03 19:29
# 40            給他屎吃   60.250.140.136 03/03 19:30
# 41           談到屎吃屎      42.74.43.70 03/03 19:35
# 42        喔，是關我...   111.83.238.151 03/03 19:35
# 43        希望他全家都得病    42.75.198.117 03/03 19:37
# 44  殺人兇手的生日，地球人的忌日      101.12.8.66 03/03 19:42
# 45             祭日吧    42.72.235.127 03/03 19:46
# 46          請他 甲塞啦  223.137.175.171 03/03 19:50
# 47     看誰同時也讓他變成忌日    49.216.63.121 03/03 19:53
# 48          幹你娘死尼哥    1.170.213.150 03/03 19:56
# 49  害死了這麼多人有心情慶祝嗎？  111.240.156.205 03/03 19:57
# 50            請他吃屎    118.171.68.25 03/03 19:59
# 51         送他到武漢旅遊  114.172.117.119 03/03 20:07
# 52       撐不到明年生日的啦    223.137.85.26 03/03 20:14

# %% [markdown]
# # 再寫一個可以看要爬幾頁的function，產出href_list

# %%
def get_href_from_page(board_name, scrap_page):
    payload={
    'from':'/bbs/'+ board_name +'/index.html',
    'yes':'yes' 
    }

    #破除18歲的限制
    rs = requests.session()
    req = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
    req = rs.get('https://www.ptt.cc/bbs/'+ board_name +'/index.html',verify = False)
    if req.status_code==200:
        web_content = req.text
        #以美味湯解析html
        soup = BeautifulSoup(web_content, 'lxml')
        pre_num = soup.select('div.btn-group > a')[3]['href'].replace('/bbs/'+board_name+'/index','') ##
        pre_num = pre_num.replace('.html','')
        total_page_index = pd.to_numeric(pre_num)+1

        url_list = []
        for i in range(total_page_index, total_page_index-scrap_page, -1):
            req = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
            req = rs.get('https://www.ptt.cc/bbs/'+ board_name +'/index'+str(i)+'.html',verify = False)
            web_content = req.text
            #以美味湯解析html
            soup = BeautifulSoup(web_content, 'lxml')
            post_list = soup.find_all('div',class_="title")
            for item in post_list:
                try:
                    url_list.append('https://www.ptt.cc'+item.select_one("a").get("href"))
                except: #刪文抓不到href
                    pass         
        return url_list
    
    else:
        return "404"

# %% [markdown]
# # 開始寫 main

# %%
def main(Board_Name, Scrap_Page):
    post_list = get_href_from_page(board_name=Board_Name, scrap_page=Scrap_Page)
    all_post_info = get_post_data(post_list[0])[0] 
    for i in range(1, len(post_list)):
        try:
            all_post_info = all_post_info.append(get_post_data(post_list[i])[0])
        except:
            pass

    all_msg = get_post_data(post_list[0])[1] 
    for i in range(1, len(post_list)):
        try:
            all_msg = all_msg.append(get_post_data(post_list[i])[1])    
        except:
            pass
    all_post_info.to_csv('all_post_info.csv')
    all_msg.to_csv('all_msg.csv')
        
    return all_post_info, all_msg

# %%
main('AGEC88',1)[0]
# Out:
#    authorId          authorName  \
# 0  BABYMING  you're my treasure
# 0       dfj              。與主同行。
# 0       dfj              。與主同行。
# 0    avstar               天涼好個秋
# 0    avstar               天涼好個秋
# 0    avstar               天涼好個秋
# 0    avstar               天涼好個秋
# 0    avstar               天涼好個秋
# 0  BABYMING  you're my treasure
# 0    avstar               天涼好個秋
# 0   PTTjane             jane wu
# 0    avstar               天涼好個秋
# 0    avstar               天涼好個秋
# 0    avstar               天涼好個秋
# 0       dfj              。與主同行。
# 0    avstar               天涼好個秋
# 0    avstar               天涼好個秋
#
#                                         canonicalUrl  \
# 0  https://www.ptt.cc/bbs/AGEC88/M.1326934346.A.5...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1327038642.A.3...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1348991955.A.E...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1356447777.A.5...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1357044966.A.6...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1360712747.A.C...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1376066385.A.F...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1392388175.A.4...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1393975370.A.9...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1398493686.A.5...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1412821196.A.7...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1417824486.A.B...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1439472906.A.4...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1441374194.A.C...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1442988569.A.7...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1523629478.A.2...
# 0  https://www.ptt.cc/bbs/AGEC88/M.1546775693.A.8...
#
#                                              content          createdTime  \
# 0    今年要不要辦班聚阿？    感覺上次聚會又過兩年了      --  ※ 發信站: 批踢...  04/03/2020 17:40:05
# 0    ※ 引述《BABYMING (you're my treasure)》之銘言：  : 今...  04/03/2020 17:40:05
# 0      下午為了記起一個遺忘的名字，    看了一下班版的精華區，    發現以前的我們真的...  04/03/2020 17:40:06
# 0    還有人在看這個版嗎???    大家快去收信    更新一下通訊錄吧~    目前只有"...  04/03/2020 17:40:07
# 0    呵呵  又過一年了    --  ※ 發信站: 批踢踢實業坊(ptt.cc)   ◆ F...  04/03/2020 17:40:07
# 0    ※ 引述《avstar (天涼好個秋)》之銘言：  : 呵呵  : 又過一年了    又...  04/03/2020 17:40:08
# 0    ※ 引述《avstar (天涼好個秋)》之銘言：  : 還有人在看這個版嗎???  : ...  04/03/2020 17:40:09
# 0    吃元宵囉~    --  ※ 發信站: 批踢踢實業坊(ptt.cc)   ◆ From:...  04/03/2020 17:40:09
# 0    大家好  我是小明，雖然現在來這的人少了  我還是先告知  我在找時間來辦同學會  目前...  04/03/2020 17:40:10
# 0    ※ 引述《BABYMING (you're my treasure)》之銘言：  : 大...  04/03/2020 17:40:11
# 0    各位農經系的學長姐大家好~~  小妹是103年系學會新任資訊部部長  今年我們的工作重點...  04/03/2020 17:40:11
#
#                                              content  \
# 0    因為本身是口交控(含到底超讚) 看到這篇實在忍不住想回    然後我是男生 不要看第一句...
#
#                                         canonicalUrl          createdTime
# 0  https://www.ptt.cc/bbs/sex/M.1583221229.A.059....  03/03/2020 21:47:25

# %%
AGEC_list = get_href_from_page(board_name='AGECservice', scrap_page=1)
# Out:
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
AGEC_list[0]
# Out:
# 'https://www.ptt.cc/bbs/AGECservice/M.1369038539.A.72F.html'

# %%
all_post_info = get_post_data(AGEC_list[0])[0] 
for i in range(1, len(AGEC_list)):
    all_post_info = all_post_info.append(get_post_data(AGEC_list[i])[0])
# Out:
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/Mac/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
all_msg = get_post_data(AGEC_list[0])[1] 
for i in range(1, len(AGEC_list)):
    all_msg = all_msg.append(get_post_data(AGEC_list[i])[1])

# %%
all_msg
# Out:
#                                         canonicalUrl push_tag     commentId  \
# 0  https://www.ptt.cc/bbs/AGECservice/M.137137434...        推       yf87008
# 0  https://www.ptt.cc/bbs/AGECservice/M.137205577...        推      etwu0718
# 0  https://www.ptt.cc/bbs/AGECservice/M.133104532...        推     achun8184
# 1  https://www.ptt.cc/bbs/AGECservice/M.133104532...        →   onemoreshot
# 2  https://www.ptt.cc/bbs/AGECservice/M.133104532...        推    pgking1224
# 0  https://www.ptt.cc/bbs/AGECservice/M.133183207...        推    bloodyjimi
# 1  https://www.ptt.cc/bbs/AGECservice/M.133183207...        推    hauerhsieh
# 2  https://www.ptt.cc/bbs/AGECservice/M.133183207...        推         syric
# 3  https://www.ptt.cc/bbs/AGECservice/M.133183207...        推         syric
# 4  https://www.ptt.cc/bbs/AGECservice/M.133183207...        推         syric
# 5  https://www.ptt.cc/bbs/AGECservice/M.133183207...        推     b00607010
# 6  https://www.ptt.cc/bbs/AGECservice/M.133183207...        →     b00607010
# 7  https://www.ptt.cc/bbs/AGECservice/M.133183207...        推     b00607010
# 8  https://www.ptt.cc/bbs/AGECservice/M.133183207...        推     b00607010
# 9  https://www.ptt.cc/bbs/AGECservice/M.133183207...        推  sara00729168
#
#                               commentContent  commentTime
# 0                                       cool  06/18 01:26
# 0                                             06/24 20:29
# 0                                     夾夾讚 頭推  03/06 23:57
# 1                         快點開工開始做事比較實在！有問題快問  03/07 01:11
# 2                            何世堯大教案好像是管理組...  03/15 22:07
# 0  3/26 農藝組  10:00~12:00  13:00~17:00   tks!  03/16 14:58
# 1           3/22 全天共六小時 B97607019 農經四 謝政豪 謝夾  03/20 14:10
# 2    4/4 農藝組 1000-1200 1300-1500 農經二 黃崇榮 謝謝！  03/25 20:10
# 3                    不好意思 想提前一天 改成4/3(二) 謝謝！  03/28 07:23
# 4      上次登記春假但農場沒開 想再登記4/20(五) 1300-1700 謝謝!  04/13 13:21
# 5            農經二陳昱如3/28,4/25,5/2 13:00~15:00  03/22 21:25
# 6            另外，日期和星期沒有對到，且 春節(4/4,4/5)可以做嗎?  03/22 21:27
# 7          3/28,4/25農藝組 5/2總務股(不好意思剛剛忘了寫，謝謝囉  03/22 21:35
# 8                              我是白癡，這是去年的!!!  03/22 21:39
# 9                                對阿  是去年的= =  03/22 23:24

# %%
pd.read_csv('all_post_info.csv')
# Out:
#     Unnamed: 0      authorId   authorName  \
# 0            0   dotcomguy20   我是謝小安  你是?
# 1            0        ace789          ace
# 2            0     bibiooooo        比比怎麼醬
# 3            0     Delightme         恬淡生活
# 4            0     Ariel0627           隨便
# 5            0       PTTjane      jane wu
# 6            0   dotcomguy20   我是謝小安  你是?
# 7            0   dotcomguy20   我是謝小安  你是?
# 8            0       damaccy          張媽媽
# 9            0        hlmomo         momo
# 10           0  AppleChicken        emily
# 11           0   dotcomguy20   我是謝小安  你是?
# 12           0  AppleChicken        emily
# 13           0        hung01       隨風來隨風去
# 14           0  AppleChicken        emily
# 15           0          agec    96年度農經系學會
# 16           0          agec    96年度農經系學會
# 17           0          ninc           濯濯
# 18           0  Ailurophilia  British-pop
# 19           0    amy1234000           方語
# 20           0      fairwind          應天風
# 21           0    cartherace    沒錯! 就這樣開始
# 22           0    crazyjimmy     找我用MSN吧~
# 23           0      kihifung       我有一把刀!
# 24           0     luckysnow   我要當妹妹唷*^^*
# 25           0     chianyaya   此刻需要的是一道曙光
# 26           0       damaccy          張媽媽
# 27           0    crazyjimmy     找我用MSN吧~
#
#                                          canonicalUrl  \
# 0   https://www.ptt.cc/bbs/AGEC93/M.1280392338.A.B...
# 1   https://www.ptt.cc/bbs/AGEC93/M.1290523414.A.8...
# 2   https://www.ptt.cc/bbs/AGEC93/M.1300295739.A.0...
# 3   https://www.ptt.cc/bbs/AGEC93/M.1308456554.A.8...
# 4   https://www.ptt.cc/bbs/AGEC93/M.1382118665.A.9...
# 5   https://www.ptt.cc/bbs/AGEC93/M.1412821358.A.7...
# 6   https://www.ptt.cc/bbs/AGEC93/M.1531407701.A.6...
# 7   https://www.ptt.cc/bbs/AGEC93/M.1552030367.A.2...
# 8   https://www.ptt.cc/bbs/AGEC93/M.1572868387.A.D...
# 9   https://www.ptt.cc/bbs/AGEC93/M.1214409674.A.1...
# 10  https://www.ptt.cc/bbs/AGEC93/M.1214459167.A.2...
# 11  https://www.ptt.cc/bbs/AGEC93/M.1214496989.A.F...
# 12  https://www.ptt.cc/bbs/AGEC93/M.1214755984.A.5...
# 13  https://www.ptt.cc/bbs/AGEC93/M.1214812819.A.B...
# 14  https://www.ptt.cc/bbs/AGEC93/M.1214829703.A.C...
# 15  https://www.ptt.cc/bbs/AGEC93/M.1220530179.A.D...
# 16  https://www.ptt.cc/bbs/AGEC93/M.1220927532.A.9...
# 17  https://www.ptt.cc/bbs/AGEC93/M.1221786092.A.4...
# 18  https://www.ptt.cc/bbs/AGEC93/M.1222238666.A.7...
# 19  https://www.ptt.cc/bbs/AGEC93/M.1226886995.A.B...
# 20  https://www.ptt.cc/bbs/AGEC93/M.1232333522.A.C...
# 21  https://www.ptt.cc/bbs/AGEC93/M.1236846096.A.E...
