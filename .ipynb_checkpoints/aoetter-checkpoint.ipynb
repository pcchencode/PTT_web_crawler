# %%
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime as dt

# %% [markdown]
# ## 先只爬一篇文章的資訊、推文留言

# %%
payload={
'from':'/bbs/'+ 'sex' +'/index.html',
'yes':'yes' 
}

url = 'https://www.ptt.cc/bbs/Examination/M.1582260742.A.8D9.html'
#url = 'https://www.ptt.cc/bbs/sex/M.1582985884.A.88A.html'
#url = 'https://www.ptt.cc/bbs/LoL/M.1583142390.A.3A0.html'
#破除18禁的限制
rs = requests.session()
req = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
req = rs.get('https://www.ptt.cc/bbs/'+ 'sex' +'/index.html',verify = False)
req = rs.get(url, verify=False)
# Out:
# /Users/GJGG/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/GJGG/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/GJGG/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/GJGG/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
#200 means get success, 404 means fail
req.status_code
# Out:
# 200

# %%
web_content = req.text
#以美味湯解析html
soup = BeautifulSoup(web_content, 'lxml')

# %%
main_content = soup.find('div',id="main-content")
metas = main_content.select('div.article-metaline')

# %%
author = metas[0].select('span.article-meta-value')[0].text
title = metas[1].select('span.article-meta-value')[0].text
post_date = metas[2].select('span.article-meta-value')[0].text

# %%
author_ID = author.split('(',1)[0].replace(' ','')
author_name = author.split('(',1)[1].replace(')','')

# %%
#content篩選出文章內文
content = soup.find(id="main-content").text
target_content=u'※ 發信站: 批踢踢實業坊(ptt.cc),'
content = content.split(target_content)
date = soup.select('.article-meta-value')[3].text
content = content[0].split(date)
content = content[1].replace('\n', '  ').replace('\t', '  ')

# %%
note = soup.select('span.f2')

# %%
org_url = note[1].text.replace('※ 文章網址: ','')

# %%
createdTime = dt.datetime.today().strftime("%d/%m/%Y %H:%M:%S")

# %%
createdTime
# Out:
# '02/03/2020 22:21:45'

# %%
post_info = []
post_info.append({'authorId':author_ID, 'authorName':author_name, 'title':title, 'publishedTime':post_date
                  , 'content':content, 'canonicalUrl':org_url, 'createdTime':createdTime})

# %%
post_info = pd.DataFrame(post_info)

# %%
pushes = main_content.find_all('div', class_='push')

# %%
push = pushes[0]

# %%
push_tag = push.find('span', 'push-tag').string.strip(' \t\n\r')
push_userid = push.find('span', 'push-userid').string.strip(' \t\n\r')
# if find is None: find().strings -> list -> ' '.join; else the current way
push_content = push.find('span', 'push-content').strings
push_content = ' '.join(push_content)[1:].strip(' \t\n\r')  # remove ':'
push_ipdatetime = push.find('span', 'push-ipdatetime').string.strip(' \t\n\r')

# %%
messages = []
for push in pushes:
    push_tag = push.find('span', 'push-tag').string.strip(' \t\n\r')
    push_userid = push.find('span', 'push-userid').string.strip(' \t\n\r')
    # if find is None: find().strings -> list -> ' '.join; else the current way
    push_content = push.find('span', 'push-content').strings
    push_content = ' '.join(push_content)[1:].strip(' \t\n\r')  # remove ':'
    push_ipdatetime = push.find('span', 'push-ipdatetime').string.strip(' \t\n\r')    
    messages.append( {'canonicalUrl':org_url, 'push_tag': push_tag, 'commentId': push_userid
                      , 'commentContent': push_content, 'commentTime': push_ipdatetime} )

# %%
messages = pd.DataFrame(messages)

# %%
messages
# Out:
#                                          canonicalUrl  \
# 0   https://www.ptt.cc/bbs/Examination/M.158226074...
# 1   https://www.ptt.cc/bbs/Examination/M.158226074...
# 2   https://www.ptt.cc/bbs/Examination/M.158226074...
# 3   https://www.ptt.cc/bbs/Examination/M.158226074...
# 4   https://www.ptt.cc/bbs/Examination/M.158226074...
# 5   https://www.ptt.cc/bbs/Examination/M.158226074...
# 26                                  沒跟到 為啥是眼鏡 什麼梗  charlie123qq  03/02 20:14
# 27                      就有天西門FB發文說眼鏡掉了，FW發文說眼鏡的主人       skyofme  03/02 20:32
# 28                               之類的吧反正一看就很像SET好的       skyofme  03/02 20:32
# 29  https://game.udn.com/game/story/10454/4263583       skyofme  03/02 20:33
# 30                           原來是附身合體 6人打比賽 這樣對嗎==       fup6456  03/02 20:49
# 31                                        在火龍臉上==     oo2751394  03/02 20:54
#
#    push_tag
# 0         推
# 1         →
# 2         推
# 3         推
# 4         推
# 5         →
# 6         推
# 7         推
# 8         推
# 9         推
# 10        推
# 11        推
# 12        →
# 13        推
# 14        推
# 15        推
# 16        推
# 17        推
# 18        推
# 19        推
# 20        推
# 21        推
# 22        推
# 23        推
# 24        →
# 25        推
# 26        推
# 27        →
# 28        →
# 29        →
# 30        →
# 31        推

# %%
pd.merge(post_info, messages, how='left', on='canonicalUrl')
# Out:
#    authorId authorName                                       canonicalUrl  \
# 0   oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 1   oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 2   oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 3   oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 4   oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 5   oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 6   oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 7   oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 8   oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 9   oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 10  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 11  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 12  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 13  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 14  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 15  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 16  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 17  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 18  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 19  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 20  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 21  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 22  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 23  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 24  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 25  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 26  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 27  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 28  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 29  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 30  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
# 31  oiuyman        man  https://www.ptt.cc/bbs/Examination/M.158226074...
#
#                                               content          createdTime  \
# 0     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 1     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 2     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 3     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 4     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 5     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 6     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 7     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 8     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 9     以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 10    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 11    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 12    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 13    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 14    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 15    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 16    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 17    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 18    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 19    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 20    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 21    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 22    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 23    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 24    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 25    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 26    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 27    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 28    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 29    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 30    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
# 31    以下代po    已經考上初等考    想在準備高普考    雖然工作算準時下班    ...  02/03/2020 22:21:45
#
#                publishedTime            title  \
# 0   Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 1   Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 2   Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 3   Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 4   Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 5   Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 6   Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 7   Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 8   Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 9   Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 10  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 11  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 12  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 13  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 14  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 15  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 16  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 17  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 18  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 19  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 20  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 21  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 22  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 23  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 24  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 25  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 26  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 27  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 28  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 29  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 30  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
# 31  Fri Feb 21 12:52:20 2020  [請益] 兼職考該怎麼安排時間
#
#                                    commentContent     commentId  commentTime  \
# 0                                         歪掉被拿去戴了     abc127845  03/02 17:48
# 1                                比較在意另一個人蘋果汁清完了嗎?     flyinside  03/02 17:53
# 2                                     我認識一個走路走很久的     smes95303  03/02 17:53
# 3                                  實況打得太糟被FW高層退貨ㄅ  AsTimeGoesBy  03/02 17:53
# 4                                       眼睛的靈壓 消失了       DON3000  03/02 17:54
# 5                                    不小心踩歪現在在火龍臉上   brian900530  03/02 17:57
# 6                                         素質不夠差==    DioEraclea  03/02 17:58
# 7                                     咪咪幫收留一下好嗎==    uglyfinger  03/02 17:59
# 8                                             可憐哪   william12tw  03/02 18:00
# 9                                              哭阿        Rektgg  03/02 18:05
# 10                                            可憐吶       UzInSec  03/02 18:11
# 11                      之前FW粉專發了一篇有人要檢起眼鏡 結果是蘭特加入  steveliuiswg  03/02 18:12
# 12                                       傳說對決 有夠爛  steveliuiswg  03/02 18:12
# 13                                 先跟屁眼俠拜個碼頭好嗎= =    kooyoo1144  03/02 18:16
# 14                                     跟阿航鍵盤一樣不見了   Charlie8522  03/02 18:18
# 15                           上次實況問西門 他也沒說什麼 就說找到了      a1230215  03/02 18:20
# 16                                        昔日AHQ之星        Manaku  03/02 18:29
# 17                                             裝B       pongbao  03/02 18:29
# 18                                            智障狼     ckniening  03/02 18:32
# 19                                        可能體檢沒過吧      kennyhen  03/02 18:56
# 20                                       被火龍撿到了==     GGthebest  03/02 19:05
# 21                                  什麼時候西門上去BP再來說      maxmeyer  03/02 19:16
# 22                                     身體太健康 電狼不收       wwl0909  03/02 19:21
# 23                                      被退貨了吧 可憐哪     hahaha630  03/02 19:40
# 24                       FW只收瘋子 西門被鑑定為精神狀態正常 無法入院    gn01914120  03/02 19:45
# 25                              閃電狼沒有健康人士保留名額嗎？哭啊    POCARI5566  03/02 19:53
# 26                                  沒跟到 為啥是眼鏡 什麼梗  charlie123qq  03/02 20:14
# 27                      就有天西門FB發文說眼鏡掉了，FW發文說眼鏡的主人       skyofme  03/02 20:32
# 28                               之類的吧反正一看就很像SET好的       skyofme  03/02 20:32
# 29  https://game.udn.com/game/story/10454/4263583       skyofme  03/02 20:33
# 30                           原來是附身合體 6人打比賽 這樣對嗎==       fup6456  03/02 20:49
# 31                                        在火龍臉上==     oo2751394  03/02 20:54
#
#    push_tag
# 0         推
# 1         →
# 2         推
# 3         推
# 4         推
# 5         →
# 6         推
# 7         推
# 8         推
# 9         推
# 10        推
# 11        推
# 12        →
# 13        推
# 14        推
# 15        推
# 16        推
# 17        推
# 18        推
# 19        推
# 20        推
# 21        推
# 22        推
# 23        推
# 24        →
# 25        推
# 26        推
# 27        →
# 28        →
# 29        →
# 30        →
# 31        推

# %% [markdown]
# ## 抓某個看板的某個頁面的所有文章網址

# %%
payload={
'from':'/bbs/'+ 'sex' +'/index.html',
'yes':'yes' 
}

url = 'https://www.ptt.cc/bbs/Examination/index.html'
#破除18禁的限制
rs = requests.session()
req = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
req = rs.get('https://www.ptt.cc/bbs/'+ 'sex' +'/index.html',verify = False)
req = rs.get(url, verify=False)
# Out:
# /Users/GJGG/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/GJGG/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/GJGG/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/GJGG/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
#200 means get success, 404 means fail
req.status_code
# Out:
# 200

# %%
web_content = req.text
#以美味湯解析html
soup = BeautifulSoup(web_content, 'lxml')

# %%
post_list = soup.find_all('div',class_="title")

# %%
url_list = []
for item in post_list:
    url_list.append('https://www.ptt.cc'+item.select_one("a").get("href"))

# %%
#得到該頁面的所有url
url_list
# Out:
# ['https://www.ptt.cc/bbs/Examination/M.1582969553.A.FEE.html',
#  'https://www.ptt.cc/bbs/Examination/M.1582979626.A.822.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583037348.A.AC9.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583038395.A.B8B.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583050146.A.269.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583050709.A.EB4.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583057947.A.E9E.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583069018.A.29E.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583075191.A.D9E.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583120282.A.3DB.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583133271.A.B3B.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583149220.A.F93.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583151717.A.0B7.html',
#  'https://www.ptt.cc/bbs/Examination/M.1583160130.A.221.html',
#  'https://www.ptt.cc/bbs/Examination/M.1526743284.A.A58.html',
#  'https://www.ptt.cc/bbs/Examination/M.1494205695.A.25E.html',
#  'https://www.ptt.cc/bbs/Examination/M.1563990333.A.6C1.html']

# %% [markdown]
# * 抓取該看板的總頁數

# %%
board = 'Examination'
pre_num = soup.select('div.btn-group > a')[3]['href'].replace('/bbs/'+board+'/index','') ##
pre_num = pre_num.replace('.html','')
total_page_index = pd.to_numeric(pre_num)+1

# %%
total_page_index
# Out:
# 3008

# %%
for i in range(3008,3002,-1):
    print(i)
# Out:
# 3008
# 3007
# 3006
# 3005
# 3004
# 3003
